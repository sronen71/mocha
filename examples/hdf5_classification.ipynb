# %% [markdown]
# # Classification with HDF5 data
#
# In this example we'll use Caffe to do simple logistic regression on a simple binary dataset, showcasing HDF5DataLayer functionality.

# %%
import os
import h5py
import shutil
import sklearn
import tempfile
import numpy as np
import pandas as pd
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# %%
# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %%
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# Accuracy: 0.762

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %%
# Run caffe. Scroll down in the output to see the final
# test accuracy, which should be about the same as above.
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver.prototxt
# Out:
# ./build/tools/caffe: /home/sronen/anaconda/lib/libtiff.so.5: no version information available (required by /usr/lib/x86_64-linux-gnu/libopencv_highgui.so.2.4)
# I1219 08:12:19.197536  6703 caffe.cpp:103] Use CPU.
# I1219 08:12:19.197872  6703 caffe.cpp:107] Starting Optimization
# I1219 08:12:19.197948  6703 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val.prototxt"
# I1219 08:12:19.197985  6703 solver.cpp:67] Creating training net from net file: examples/hdf5_classification/train_val.prototxt
# I1219 08:12:19.207952  6703 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I1219 08:12:19.208019  6703 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I1219 08:12:19.208122  6703 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I1219 08:12:19.208232  6703 net.cpp:67] Creating Layer data
# I1219 08:12:19.208267  6703 net.cpp:356] data -> data
# I1219 08:12:19.208320  6703 net.cpp:356] data -> label
# I1219 08:12:19.208371  6703 net.cpp:96] Setting up data
# I1219 08:12:19.208401  6703 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I1219 08:12:19.208597  6703 hdf5_data_layer.cpp:69] Number of files: 2
# I1219 08:12:19.208636  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.212216  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.212349  6703 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:19.212419  6703 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:19.212467  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.212527  6703 net.cpp:67] Creating Layer fc1
# I1219 08:12:19.212638  6703 net.cpp:394] fc1 <- data
# I1219 08:12:19.212725  6703 net.cpp:356] fc1 -> fc1
# I1219 08:12:19.212784  6703 net.cpp:96] Setting up fc1
# I1219 08:12:19.213342  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.213465  6703 net.cpp:67] Creating Layer loss
# I1219 08:12:19.213505  6703 net.cpp:394] loss <- fc1
# I1219 08:12:19.213544  6703 net.cpp:394] loss <- label
# I1219 08:12:19.213584  6703 net.cpp:356] loss -> loss
# I1219 08:12:19.213628  6703 net.cpp:96] Setting up loss
# I1219 08:12:19.213696  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.213733  6703 net.cpp:109]     with loss weight 1
# I1219 08:12:19.213799  6703 net.cpp:170] loss needs backward computation.
# I1219 08:12:19.213855  6703 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:19.213891  6703 net.cpp:172] data does not need backward computation.
# I1219 08:12:19.213922  6703 net.cpp:208] This network produces output loss
# I1219 08:12:19.213975  6703 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:19.214011  6703 net.cpp:219] Network initialization done.
# I1219 08:12:19.214045  6703 net.cpp:220] Memory required for data: 284
# I1219 08:12:19.214393  6703 solver.cpp:151] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val.prototxt
# I1219 08:12:19.214450  6703 net.cpp:275] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I1219 08:12:19.214558  6703 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I1219 08:12:19.215701  6703 net.cpp:67] Creating Layer data
# I1219 08:12:19.215749  6703 net.cpp:356] data -> data
# I1219 08:12:19.215814  6703 net.cpp:356] data -> label
# I1219 08:12:19.215854  6703 net.cpp:96] Setting up data
# I1219 08:12:19.215888  6703 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I1219 08:12:19.215970  6703 hdf5_data_layer.cpp:69] Number of files: 1
# I1219 08:12:19.216006  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/test.h5
# I1219 08:12:19.217787  6703 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I1219 08:12:19.217942  6703 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:19.217983  6703 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:19.218018  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218060  6703 net.cpp:67] Creating Layer label_data_1_split
# I1219 08:12:19.218093  6703 net.cpp:394] label_data_1_split <- label
# I1219 08:12:19.218130  6703 net.cpp:356] label_data_1_split -> label_data_1_split_0
# I1219 08:12:19.218339  6703 net.cpp:356] label_data_1_split -> label_data_1_split_1
# I1219 08:12:19.218389  6703 net.cpp:96] Setting up label_data_1_split
# I1219 08:12:19.218431  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218534  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218593  6703 net.cpp:67] Creating Layer fc1
# I1219 08:12:19.218631  6703 net.cpp:394] fc1 <- data
# I1219 08:12:19.218668  6703 net.cpp:356] fc1 -> fc1
# I1219 08:12:19.218708  6703 net.cpp:96] Setting up fc1
# I1219 08:12:19.218752  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.218798  6703 net.cpp:67] Creating Layer fc1_fc1_0_split
# I1219 08:12:19.218848  6703 net.cpp:394] fc1_fc1_0_split <- fc1
# I1219 08:12:19.218888  6703 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_0
# I1219 08:12:19.218925  6703 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_1
# I1219 08:12:19.218962  6703 net.cpp:96] Setting up fc1_fc1_0_split
# I1219 08:12:19.219015  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.219049  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.219081  6703 net.cpp:67] Creating Layer loss
# I1219 08:12:19.219135  6703 net.cpp:394] loss <- fc1_fc1_0_split_0
# I1219 08:12:19.219169  6703 net.cpp:394] loss <- label_data_1_split_0
# I1219 08:12:19.219205  6703 net.cpp:356] loss -> loss
# I1219 08:12:19.219243  6703 net.cpp:96] Setting up loss
# I1219 08:12:19.219280  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.219312  6703 net.cpp:109]     with loss weight 1
# I1219 08:12:19.219358  6703 net.cpp:67] Creating Layer accuracy
# I1219 08:12:19.219422  6703 net.cpp:394] accuracy <- fc1_fc1_0_split_1
# I1219 08:12:19.219450  6703 net.cpp:394] accuracy <- label_data_1_split_1
# I1219 08:12:19.219476  6703 net.cpp:356] accuracy -> accuracy
# I1219 08:12:19.219506  6703 net.cpp:96] Setting up accuracy
# I1219 08:12:19.219534  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.219558  6703 net.cpp:172] accuracy does not need backward computation.
# I1219 08:12:19.219580  6703 net.cpp:170] loss needs backward computation.
# I1219 08:12:19.219604  6703 net.cpp:170] fc1_fc1_0_split needs backward computation.
# I1219 08:12:19.219627  6703 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:19.219673  6703 net.cpp:172] label_data_1_split does not need backward computation.
# I1219 08:12:19.219699  6703 net.cpp:172] data does not need backward computation.
# I1219 08:12:19.219758  6703 net.cpp:208] This network produces output accuracy
# I1219 08:12:19.219784  6703 net.cpp:208] This network produces output loss
# I1219 08:12:19.219811  6703 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:19.219856  6703 net.cpp:219] Network initialization done.
# I1219 08:12:19.219885  6703 net.cpp:220] Memory required for data: 528
# I1219 08:12:19.219923  6703 solver.cpp:41] Solver scaffolding done.
# I1219 08:12:19.219967  6703 solver.cpp:160] Solving LogisticRegressionNet
# I1219 08:12:19.219998  6703 solver.cpp:247] Iteration 0, Testing net (#0)
# I1219 08:12:19.228442  6703 solver.cpp:298]     Test net output #0: accuracy = 0.6956
# I1219 08:12:19.228569  6703 solver.cpp:298]     Test net output #1: loss = 0.688362 (* 1 = 0.688362 loss)
# I1219 08:12:19.228648  6703 solver.cpp:191] Iteration 0, loss = 0.695054
# I1219 08:12:19.228683  6703 solver.cpp:206]     Train net output #0: loss = 0.695054 (* 1 = 0.695054 loss)
# I1219 08:12:19.228715  6703 solver.cpp:403] Iteration 0, lr = 0.01
# I1219 08:12:19.232967  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.233537  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.236044  6703 solver.cpp:247] Iteration 1000, Testing net (#0)
# I1219 08:12:19.252324  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7552
# I1219 08:12:19.252627  6703 solver.cpp:298]     Test net output #1: loss = 0.594086 (* 1 = 0.594086 loss)
# I1219 08:12:19.252799  6703 solver.cpp:191] Iteration 1000, loss = 0.470893
# I1219 08:12:19.252857  6703 solver.cpp:206]     Train net output #0: loss = 0.470893 (* 1 = 0.470893 loss)
# I1219 08:12:19.252900  6703 solver.cpp:403] Iteration 1000, lr = 0.01
# I1219 08:12:19.256023  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.256152  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.256988  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.261559  6703 solver.cpp:247] Iteration 2000, Testing net (#0)
# I1219 08:12:19.271371  6703 solver.cpp:298]     Test net output #0: accuracy = 0.774
# I1219 08:12:19.271455  6703 solver.cpp:298]     Test net output #1: loss = 0.595628 (* 1 = 0.595628 loss)
# I1219 08:12:19.271498  6703 solver.cpp:191] Iteration 2000, loss = 0.76071
# I1219 08:12:19.271538  6703 solver.cpp:206]     Train net output #0: loss = 0.76071 (* 1 = 0.76071 loss)
# I1219 08:12:19.271669  6703 solver.cpp:403] Iteration 2000, lr = 0.01
# I1219 08:12:19.272680  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.273214  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.277489  6703 solver.cpp:247] Iteration 3000, Testing net (#0)
# I1219 08:12:19.283244  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7628
# I1219 08:12:19.283325  6703 solver.cpp:298]     Test net output #1: loss = 0.593084 (* 1 = 0.593084 loss)
# I1219 08:12:19.283356  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.283411  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.284180  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.284324  6703 solver.cpp:191] Iteration 3000, loss = 0.786944
# I1219 08:12:19.284369  6703 solver.cpp:206]     Train net output #0: loss = 0.786944 (* 1 = 0.786944 loss)
# I1219 08:12:19.284399  6703 solver.cpp:403] Iteration 3000, lr = 0.01
# I1219 08:12:19.290078  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.290947  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.292816  6703 solver.cpp:247] Iteration 4000, Testing net (#0)
# I1219 08:12:19.303151  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7552
# I1219 08:12:19.303288  6703 solver.cpp:298]     Test net output #1: loss = 0.594086 (* 1 = 0.594086 loss)
# I1219 08:12:19.303395  6703 solver.cpp:191] Iteration 4000, loss = 0.470893
# I1219 08:12:19.303429  6703 solver.cpp:206]     Train net output #0: loss = 0.470893 (* 1 = 0.470893 loss)
# I1219 08:12:19.303457  6703 solver.cpp:403] Iteration 4000, lr = 0.01
# I1219 08:12:19.306126  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.306265  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.307286  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.309453  6703 solver.cpp:247] Iteration 5000, Testing net (#0)
# I1219 08:12:19.317893  6703 solver.cpp:298]     Test net output #0: accuracy = 0.774
# I1219 08:12:19.317991  6703 solver.cpp:298]     Test net output #1: loss = 0.595628 (* 1 = 0.595628 loss)
# I1219 08:12:19.318050  6703 solver.cpp:191] Iteration 5000, loss = 0.76071
# I1219 08:12:19.318096  6703 solver.cpp:206]     Train net output #0: loss = 0.76071 (* 1 = 0.76071 loss)
# I1219 08:12:19.318136  6703 solver.cpp:403] Iteration 5000, lr = 0.001
# I1219 08:12:19.320324  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.320791  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.325198  6703 solver.cpp:247] Iteration 6000, Testing net (#0)
# I1219 08:12:19.333302  6703 solver.cpp:298]     Test net output #0: accuracy = 0.761601
# I1219 08:12:19.333483  6703 solver.cpp:298]     Test net output #1: loss = 0.591837 (* 1 = 0.591837 loss)
# I1219 08:12:19.333539  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.333580  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.334617  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.334795  6703 solver.cpp:191] Iteration 6000, loss = 0.772234
# I1219 08:12:19.334863  6703 solver.cpp:206]     Train net output #0: loss = 0.772234 (* 1 = 0.772234 loss)
# I1219 08:12:19.334911  6703 solver.cpp:403] Iteration 6000, lr = 0.001
# I1219 08:12:19.339965  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.340620  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.341912  6703 solver.cpp:247] Iteration 7000, Testing net (#0)
# I1219 08:12:19.349477  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7664
# I1219 08:12:19.349639  6703 solver.cpp:298]     Test net output #1: loss = 0.59251 (* 1 = 0.59251 loss)
# I1219 08:12:19.349696  6703 solver.cpp:191] Iteration 7000, loss = 0.516432
# I1219 08:12:19.349730  6703 solver.cpp:206]     Train net output #0: loss = 0.516432 (* 1 = 0.516432 loss)
# I1219 08:12:19.349758  6703 solver.cpp:403] Iteration 7000, lr = 0.001
# I1219 08:12:19.352972  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.353129  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.353811  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.357167  6703 solver.cpp:247] Iteration 8000, Testing net (#0)
# I1219 08:12:19.363391  6703 solver.cpp:298]     Test net output #0: accuracy = 0.768
# I1219 08:12:19.363477  6703 solver.cpp:298]     Test net output #1: loss = 0.591181 (* 1 = 0.591181 loss)
# I1219 08:12:19.363528  6703 solver.cpp:191] Iteration 8000, loss = 0.795977
# I1219 08:12:19.363560  6703 solver.cpp:206]     Train net output #0: loss = 0.795977 (* 1 = 0.795977 loss)
# I1219 08:12:19.363591  6703 solver.cpp:403] Iteration 8000, lr = 0.001
# I1219 08:12:19.364802  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.365473  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.368908  6703 solver.cpp:247] Iteration 9000, Testing net (#0)
# I1219 08:12:19.374877  6703 solver.cpp:298]     Test net output #0: accuracy = 0.762801
# I1219 08:12:19.375004  6703 solver.cpp:298]     Test net output #1: loss = 0.591795 (* 1 = 0.591795 loss)
# I1219 08:12:19.375072  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.375097  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.375604  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.375681  6703 solver.cpp:191] Iteration 9000, loss = 0.77468
# I1219 08:12:19.375772  6703 solver.cpp:206]     Train net output #0: loss = 0.77468 (* 1 = 0.77468 loss)
# I1219 08:12:19.375802  6703 solver.cpp:403] Iteration 9000, lr = 0.001
# I1219 08:12:19.379832  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.380620  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.382009  6703 solver.cpp:317] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I1219 08:12:19.382411  6703 solver.cpp:324] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.solverstate
# I1219 08:12:19.382501  6703 solver.cpp:228] Iteration 10000, loss = 0.516244
# I1219 08:12:19.382596  6703 solver.cpp:247] Iteration 10000, Testing net (#0)
# I1219 08:12:19.388818  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7664
# I1219 08:12:19.389006  6703 solver.cpp:298]     Test net output #1: loss = 0.592505 (* 1 = 0.592505 loss)
# I1219 08:12:19.389040  6703 solver.cpp:233] Optimization Done.
# I1219 08:12:19.389065  6703 caffe.cpp:121] Optimization Done.

# %% [markdown]
# If you look at the `train_val.prototxt`, you'll see that it's simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer neural network.
# That network is given in `train_val2.prototxt`, and that's the only change made in `solver2.prototxt` which we will now use.
#
# The final accuracy of the network we'll train below should be higher than for the network above!

# %%
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver2.prototxt
# Out:
# I0220 01:32:09.925078 16808 caffe.cpp:103] Use CPU.
# I0220 01:32:10.059752 16808 caffe.cpp:107] Starting Optimization
# I0220 01:32:10.059829 16808 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val2.prototxt"
# I0220 01:32:10.059873 16808 solver.cpp:67] Creating training net from net file: examples/hdf5_classification/train_val2.prototxt
# I0220 01:32:10.060217 16808 net.cpp:288] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0220 01:32:10.060243 16808 net.cpp:288] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0220 01:32:10.060288 16808 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I0220 01:32:10.060448 16808 net.cpp:67] Creating Layer data
# I0220 01:32:10.060456 16808 net.cpp:369] data -> data
# I0220 01:32:10.060472 16808 net.cpp:369] data -> label
# I0220 01:32:10.060482 16808 net.cpp:97] Setting up data
# I0220 01:32:10.060487 16808 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I0220 01:32:10.060539 16808 hdf5_data_layer.cpp:69] Number of files: 2
# I0220 01:32:10.060546 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.061436 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.061460 16808 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0220 01:32:10.061468 16808 net.cpp:104] Top shape: 10 4 1 1 (40)
# I0220 01:32:10.061475 16808 net.cpp:104] Top shape: 10 1 1 1 (10)
# I0220 01:32:10.061483 16808 net.cpp:67] Creating Layer fc1
# I0220 01:32:10.061488 16808 net.cpp:407] fc1 <- data
# blob need backward: 1 0 0
# I0220 01:32:10.061511 16808 net.cpp:369] fc1 -> fc1
# I0220 01:32:10.061519 16808 net.cpp:97] Setting up fc1
# I0220 01:32:10.061864 16808 net.cpp:104] Top shape: 10 40 1 1 (400)
# set blob_need_backward 1 2
# I0220 01:32:10.061893 16808 net.cpp:67] Creating Layer relu1
# I0220 01:32:10.061898 16808 net.cpp:407] relu1 <- fc1
# blob need backward: 2 2 1
# I0220 01:32:10.061908 16808 net.cpp:358] relu1 -> fc1 (in-place)
# I0220 01:32:10.061923 16808 net.cpp:97] Setting up relu1
# I0220 01:32:10.070441 16808 net.cpp:104] Top shape: 10 40 1 1 (400)
# set blob_need_backward 2 2
# I0220 01:32:10.070482 16808 net.cpp:67] Creating Layer fc2
# I0220 01:32:10.070487 16808 net.cpp:407] fc2 <- fc1
# blob need backward: 3 2 1
# I0220 01:32:10.070498 16808 net.cpp:369] fc2 -> fc2
# I0220 01:32:10.070508 16808 net.cpp:97] Setting up fc2
# I0220 01:32:10.070520 16808 net.cpp:104] Top shape: 10 2 1 1 (20)
# set blob_need_backward 3 3
# I0220 01:32:10.070535 16808 net.cpp:67] Creating Layer loss
# I0220 01:32:10.070539 16808 net.cpp:407] loss <- fc2
# blob need backward: 4 3 1
# I0220 01:32:10.070546 16808 net.cpp:407] loss <- label
# blob need backward: 4 1 0
# I0220 01:32:10.070556 16808 net.cpp:369] loss -> loss
# I0220 01:32:10.070562 16808 net.cpp:97] Setting up loss
# I0220 01:32:10.070574 16808 net.cpp:104] Top shape: 1 1 1 1 (1)
# I0220 01:32:10.070577 16808 net.cpp:110]     with loss weight 1
# set blob_need_backward 4 4
# I0220 01:32:10.070600 16808 net.cpp:183] loss needs backward computation.
# I0220 01:32:10.070626 16808 net.cpp:183] fc2 needs backward computation.
# I0220 01:32:10.070631 16808 net.cpp:183] relu1 needs backward computation.
# I0220 01:32:10.070634 16808 net.cpp:183] fc1 needs backward computation.
# I0220 01:32:10.070638 16808 net.cpp:185] data does not need backward computation.
# I0220 01:32:10.070643 16808 net.cpp:221] This network produces output loss
# I0220 01:32:10.070649 16808 net.cpp:481] Collecting Learning Rate and Weight Decay.
# I0220 01:32:10.070654 16808 net.cpp:232] Network initialization done.
# I0220 01:32:10.070658 16808 net.cpp:233] Memory required for data: 3484
# I0220 01:32:10.070847 16808 solver.cpp:151] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val2.prototxt
# I0220 01:32:10.070863 16808 net.cpp:288] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0220 01:32:10.070910 16808 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I0220 01:32:10.071080 16808 net.cpp:67] Creating Layer data
# I0220 01:32:10.071087 16808 net.cpp:369] data -> data
# I0220 01:32:10.071094 16808 net.cpp:369] data -> label
# I0220 01:32:10.071100 16808 net.cpp:97] Setting up data
# I0220 01:32:10.071105 16808 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I0220 01:32:10.071123 16808 hdf5_data_layer.cpp:69] Number of files: 1
# I0220 01:32:10.071130 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/test.h5
# I0220 01:32:10.071997 16808 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I0220 01:32:10.072020 16808 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0220 01:32:10.072026 16808 net.cpp:104] Top shape: 10 4 1 1 (40)
# I0220 01:32:10.072039 16808 net.cpp:104] Top shape: 10 1 1 1 (10)
# I0220 01:32:10.072046 16808 net.cpp:67] Creating Layer label_data_1_split
# I0220 01:32:10.072052 16808 net.cpp:407] label_data_1_split <- label
# blob need backward: 1 1 0
# I0220 01:32:10.072060 16808 net.cpp:369] label_data_1_split -> label_data_1_split_0
# I0220 01:32:10.072067 16808 net.cpp:369] label_data_1_split -> label_data_1_split_1
# I0220 01:32:10.072073 16808 net.cpp:97] Setting up label_data_1_split
# I0220 01:32:10.072079 16808 net.cpp:104] Top shape: 10 1 1 1 (10)
# I0220 01:32:10.072084 16808 net.cpp:104] Top shape: 10 1 1 1 (10)
# I0220 01:32:10.072090 16808 net.cpp:67] Creating Layer fc1
# I0220 01:32:10.072095 16808 net.cpp:407] fc1 <- data
# blob need backward: 2 0 0
# I0220 01:32:10.072103 16808 net.cpp:369] fc1 -> fc1
# I0220 01:32:10.072110 16808 net.cpp:97] Setting up fc1
# I0220 01:32:10.072123 16808 net.cpp:104] Top shape: 10 40 1 1 (400)
# set blob_need_backward 2 4
# I0220 01:32:10.072134 16808 net.cpp:67] Creating Layer relu1
# I0220 01:32:10.072139 16808 net.cpp:407] relu1 <- fc1
# blob need backward: 3 4 1
# I0220 01:32:10.072146 16808 net.cpp:358] relu1 -> fc1 (in-place)
# I0220 01:32:10.072151 16808 net.cpp:97] Setting up relu1
# I0220 01:32:10.072161 16808 net.cpp:104] Top shape: 10 40 1 1 (400)
# set blob_need_backward 3 4
# I0220 01:32:10.072182 16808 net.cpp:67] Creating Layer fc2
# I0220 01:32:10.072186 16808 net.cpp:407] fc2 <- fc1
# blob need backward: 4 4 1
# I0220 01:32:10.072196 16808 net.cpp:369] fc2 -> fc2
# I0220 01:32:10.072201 16808 net.cpp:97] Setting up fc2
# I0220 01:32:10.072211 16808 net.cpp:104] Top shape: 10 2 1 1 (20)
# set blob_need_backward 4 5
# I0220 01:32:10.072221 16808 net.cpp:67] Creating Layer fc2_fc2_0_split
# I0220 01:32:10.072224 16808 net.cpp:407] fc2_fc2_0_split <- fc2
# blob need backward: 5 5 1
# I0220 01:32:10.072232 16808 net.cpp:369] fc2_fc2_0_split -> fc2_fc2_0_split_0
# I0220 01:32:10.072238 16808 net.cpp:369] fc2_fc2_0_split -> fc2_fc2_0_split_1
# I0220 01:32:10.072244 16808 net.cpp:97] Setting up fc2_fc2_0_split
# I0220 01:32:10.072248 16808 net.cpp:104] Top shape: 10 2 1 1 (20)
# I0220 01:32:10.072253 16808 net.cpp:104] Top shape: 10 2 1 1 (20)
# set blob_need_backward 5 6
# set blob_need_backward 5 7
# I0220 01:32:10.072263 16808 net.cpp:67] Creating Layer loss
# I0220 01:32:10.072268 16808 net.cpp:407] loss <- fc2_fc2_0_split_0
# blob need backward: 6 6 1
# I0220 01:32:10.072274 16808 net.cpp:407] loss <- label_data_1_split_0
# blob need backward: 6 2 0
# I0220 01:32:10.072283 16808 net.cpp:369] loss -> loss
# I0220 01:32:10.072288 16808 net.cpp:97] Setting up loss
# I0220 01:32:10.072294 16808 net.cpp:104] Top shape: 1 1 1 1 (1)
# I0220 01:32:10.072299 16808 net.cpp:110]     with loss weight 1
# set blob_need_backward 6 8
# I0220 01:32:10.072309 16808 net.cpp:67] Creating Layer accuracy
# I0220 01:32:10.072312 16808 net.cpp:407] accuracy <- fc2_fc2_0_split_1
# blob need backward: 7 7 1
# I0220 01:32:10.072319 16808 net.cpp:407] accuracy <- label_data_1_split_1
# blob need backward: 7 3 0
# I0220 01:32:10.072327 16808 net.cpp:369] accuracy -> accuracy
# I0220 01:32:10.072332 16808 net.cpp:97] Setting up accuracy
# I0220 01:32:10.088771 16808 net.cpp:104] Top shape: 1 1 1 1 (1)
# set blob_need_backward 7 9
# I0220 01:32:10.088788 16808 net.cpp:185] accuracy does not need backward computation.
# I0220 01:32:10.088793 16808 net.cpp:183] loss needs backward computation.
# I0220 01:32:10.088798 16808 net.cpp:183] fc2_fc2_0_split needs backward computation.
# I0220 01:32:10.088803 16808 net.cpp:183] fc2 needs backward computation.
# I0220 01:32:10.088807 16808 net.cpp:183] relu1 needs backward computation.
# I0220 01:32:10.088812 16808 net.cpp:183] fc1 needs backward computation.
# I0220 01:32:10.088816 16808 net.cpp:185] label_data_1_split does not need backward computation.
# I0220 01:32:10.088820 16808 net.cpp:185] data does not need backward computation.
# I0220 01:32:10.088825 16808 net.cpp:221] This network produces output accuracy
# I0220 01:32:10.088829 16808 net.cpp:221] This network produces output loss
# I0220 01:32:10.088839 16808 net.cpp:481] Collecting Learning Rate and Weight Decay.
# I0220 01:32:10.088843 16808 net.cpp:232] Network initialization done.
# I0220 01:32:10.088847 16808 net.cpp:233] Memory required for data: 3728
# I0220 01:32:10.088867 16808 solver.cpp:41] Solver scaffolding done.
# I0220 01:32:10.088873 16808 solver.cpp:160] Solving LogisticRegressionNet
# I0220 01:32:10.088877 16808 solver.cpp:161] Learning Rate Policy: step
# I0220 01:32:10.088888 16808 solver.cpp:268] Iteration 0, Testing net (#0)
# I0220 01:32:10.149896 16808 solver.cpp:319]     Test net output #0: accuracy = 0.531201
# I0220 01:32:10.149929 16808 solver.cpp:319]     Test net output #1: loss = 0.693121 (* 1 = 0.693121 loss)
# I0220 01:32:10.149965 16808 solver.cpp:213] Iteration 0, loss = 0.693133
# I0220 01:32:10.149973 16808 solver.cpp:228]     Train net output #0: loss = 0.693133 (* 1 = 0.693133 loss)
# I0220 01:32:10.149981 16808 solver.cpp:450] Iteration 0, lr = 0.01
# I0220 01:32:10.156298 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.156654 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.158769 16808 solver.cpp:268] Iteration 1000, Testing net (#0)
# I0220 01:32:10.165402 16808 solver.cpp:319]     Test net output #0: accuracy = 0.7448
# I0220 01:32:10.165437 16808 solver.cpp:319]     Test net output #1: loss = 0.512493 (* 1 = 0.512493 loss)
# I0220 01:32:10.165457 16808 solver.cpp:213] Iteration 1000, loss = 0.450008
# I0220 01:32:10.165465 16808 solver.cpp:228]     Train net output #0: loss = 0.450009 (* 1 = 0.450009 loss)
# I0220 01:32:10.165472 16808 solver.cpp:450] Iteration 1000, lr = 0.01
# I0220 01:32:10.169955 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.169967 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.170335 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.174553 16808 solver.cpp:268] Iteration 2000, Testing net (#0)
# I0220 01:32:10.180945 16808 solver.cpp:319]     Test net output #0: accuracy = 0.7484
# I0220 01:32:10.180963 16808 solver.cpp:319]     Test net output #1: loss = 0.502649 (* 1 = 0.502649 loss)
# I0220 01:32:10.180979 16808 solver.cpp:213] Iteration 2000, loss = 0.403842
# I0220 01:32:10.180985 16808 solver.cpp:228]     Train net output #0: loss = 0.403843 (* 1 = 0.403843 loss)
# I0220 01:32:10.180991 16808 solver.cpp:450] Iteration 2000, lr = 0.01
# I0220 01:32:10.183429 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.183681 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.190163 16808 solver.cpp:268] Iteration 3000, Testing net (#0)
# I0220 01:32:10.196774 16808 solver.cpp:319]     Test net output #0: accuracy = 0.798
# I0220 01:32:10.196795 16808 solver.cpp:319]     Test net output #1: loss = 0.448371 (* 1 = 0.448371 loss)
# I0220 01:32:10.196801 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.196806 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.197046 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.197069 16808 solver.cpp:213] Iteration 3000, loss = 0.544322
# I0220 01:32:10.197079 16808 solver.cpp:228]     Train net output #0: loss = 0.544323 (* 1 = 0.544323 loss)
# I0220 01:32:10.197084 16808 solver.cpp:450] Iteration 3000, lr = 0.01
# I0220 01:32:10.203460 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.203692 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.205904 16808 solver.cpp:268] Iteration 4000, Testing net (#0)
# I0220 01:32:10.212580 16808 solver.cpp:319]     Test net output #0: accuracy = 0.712
# I0220 01:32:10.212610 16808 solver.cpp:319]     Test net output #1: loss = 0.506612 (* 1 = 0.506612 loss)
# I0220 01:32:10.212630 16808 solver.cpp:213] Iteration 4000, loss = 0.398821
# I0220 01:32:10.212638 16808 solver.cpp:228]     Train net output #0: loss = 0.398821 (* 1 = 0.398821 loss)
# I0220 01:32:10.212653 16808 solver.cpp:450] Iteration 4000, lr = 0.01
# I0220 01:32:10.217027 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.217051 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.217474 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.221905 16808 solver.cpp:268] Iteration 5000, Testing net (#0)
# I0220 01:32:10.228407 16808 solver.cpp:319]     Test net output #0: accuracy = 0.813201
# I0220 01:32:10.228433 16808 solver.cpp:319]     Test net output #1: loss = 0.427478 (* 1 = 0.427478 loss)
# I0220 01:32:10.228449 16808 solver.cpp:213] Iteration 5000, loss = 0.339679
# I0220 01:32:10.228457 16808 solver.cpp:228]     Train net output #0: loss = 0.33968 (* 1 = 0.33968 loss)
# I0220 01:32:10.228472 16808 solver.cpp:450] Iteration 5000, lr = 0.001
# I0220 01:32:10.230731 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.231086 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.237557 16808 solver.cpp:268] Iteration 6000, Testing net (#0)
# I0220 01:32:10.244011 16808 solver.cpp:319]     Test net output #0: accuracy = 0.820801
# I0220 01:32:10.244036 16808 solver.cpp:319]     Test net output #1: loss = 0.41538 (* 1 = 0.41538 loss)
# I0220 01:32:10.244042 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.244047 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.244317 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.244370 16808 solver.cpp:213] Iteration 6000, loss = 0.479707
# I0220 01:32:10.244381 16808 solver.cpp:228]     Train net output #0: loss = 0.479708 (* 1 = 0.479708 loss)
# I0220 01:32:10.244387 16808 solver.cpp:450] Iteration 6000, lr = 0.001
# I0220 01:32:10.250764 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.251013 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.253176 16808 solver.cpp:268] Iteration 7000, Testing net (#0)
# I0220 01:32:10.259827 16808 solver.cpp:319]     Test net output #0: accuracy = 0.8216
# I0220 01:32:10.259850 16808 solver.cpp:319]     Test net output #1: loss = 0.411882 (* 1 = 0.411882 loss)
# I0220 01:32:10.259866 16808 solver.cpp:213] Iteration 7000, loss = 0.307883
# I0220 01:32:10.259874 16808 solver.cpp:228]     Train net output #0: loss = 0.307884 (* 1 = 0.307884 loss)
# I0220 01:32:10.259888 16808 solver.cpp:450] Iteration 7000, lr = 0.001
# I0220 01:32:10.264163 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.264185 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.264492 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.268827 16808 solver.cpp:268] Iteration 8000, Testing net (#0)
# I0220 01:32:10.275745 16808 solver.cpp:319]     Test net output #0: accuracy = 0.819201
# I0220 01:32:10.275775 16808 solver.cpp:319]     Test net output #1: loss = 0.412349 (* 1 = 0.412349 loss)
# I0220 01:32:10.275794 16808 solver.cpp:213] Iteration 8000, loss = 0.272614
# I0220 01:32:10.275801 16808 solver.cpp:228]     Train net output #0: loss = 0.272616 (* 1 = 0.272616 loss)
# I0220 01:32:10.275807 16808 solver.cpp:450] Iteration 8000, lr = 0.001
# I0220 01:32:10.278067 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.278395 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.284668 16808 solver.cpp:268] Iteration 9000, Testing net (#0)
# I0220 01:32:10.291265 16808 solver.cpp:319]     Test net output #0: accuracy = 0.82
# I0220 01:32:10.291288 16808 solver.cpp:319]     Test net output #1: loss = 0.412537 (* 1 = 0.412537 loss)
# I0220 01:32:10.291293 16808 hdf5_data_layer.cpp:99] looping around to first file
# I0220 01:32:10.291298 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.291532 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.291574 16808 solver.cpp:213] Iteration 9000, loss = 0.457037
# I0220 01:32:10.291584 16808 solver.cpp:228]     Train net output #0: loss = 0.457038 (* 1 = 0.457038 loss)
# I0220 01:32:10.291589 16808 solver.cpp:450] Iteration 9000, lr = 0.001
# I0220 01:32:10.297991 16808 hdf5_data_layer.cpp:29] Loading HDF5 file/home/shai/mocha/examples/hdf5_classification/data/train.h5
# I0220 01:32:10.298233 16808 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0220 01:32:10.300422 16808 solver.cpp:339] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I0220 01:32:10.300524 16808 solver.cpp:347] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.solverstate
# I0220 01:32:10.300571 16808 solver.cpp:250] Iteration 10000, loss = 0.300657
# I0220 01:32:10.300581 16808 solver.cpp:268] Iteration 10000, Testing net (#0)
# I0220 01:32:10.307164 16808 solver.cpp:319]     Test net output #0: accuracy = 0.8224
# I0220 01:32:10.307185 16808 solver.cpp:319]     Test net output #1: loss = 0.409263 (* 1 = 0.409263 loss)
# I0220 01:32:10.307191 16808 solver.cpp:255] Optimization Done.
# I0220 01:32:10.307196 16808 caffe.cpp:121] Optimization Done.

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
