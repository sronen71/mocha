# %% [markdown]
# # Classification with HDF5 data
#
# In this example we'll use Caffe to do simple logistic regression on a simple binary dataset, showcasing HDF5DataLayer functionality.

# %%
import os
import h5py
import shutil
import sklearn
import tempfile
import numpy as np
import pandas as pd
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# %%
# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %%
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# Accuracy: 0.767

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %%
# Run caffe. Scroll down in the output to see the final
# test accuracy, which should be about the same as above.
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver.prototxt
# Out:
# ./build/tools/caffe: /home/sronen/anaconda/lib/libtiff.so.5: no version information available (required by /usr/lib/x86_64-linux-gnu/libopencv_highgui.so.2.4)
# I1219 08:12:19.197536  6703 caffe.cpp:103] Use CPU.
# I1219 08:12:19.197872  6703 caffe.cpp:107] Starting Optimization
# I1219 08:12:19.197948  6703 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val.prototxt"
# I1219 08:12:19.197985  6703 solver.cpp:67] Creating training net from net file: examples/hdf5_classification/train_val.prototxt
# I1219 08:12:19.207952  6703 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I1219 08:12:19.208019  6703 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I1219 08:12:19.208122  6703 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I1219 08:12:19.208232  6703 net.cpp:67] Creating Layer data
# I1219 08:12:19.208267  6703 net.cpp:356] data -> data
# I1219 08:12:19.208320  6703 net.cpp:356] data -> label
# I1219 08:12:19.208371  6703 net.cpp:96] Setting up data
# I1219 08:12:19.208401  6703 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I1219 08:12:19.208597  6703 hdf5_data_layer.cpp:69] Number of files: 2
# I1219 08:12:19.208636  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.212216  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.212349  6703 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:19.212419  6703 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:19.212467  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.212527  6703 net.cpp:67] Creating Layer fc1
# I1219 08:12:19.212638  6703 net.cpp:394] fc1 <- data
# I1219 08:12:19.212725  6703 net.cpp:356] fc1 -> fc1
# I1219 08:12:19.212784  6703 net.cpp:96] Setting up fc1
# I1219 08:12:19.213342  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.213465  6703 net.cpp:67] Creating Layer loss
# I1219 08:12:19.213505  6703 net.cpp:394] loss <- fc1
# I1219 08:12:19.213544  6703 net.cpp:394] loss <- label
# I1219 08:12:19.213584  6703 net.cpp:356] loss -> loss
# I1219 08:12:19.213628  6703 net.cpp:96] Setting up loss
# I1219 08:12:19.213696  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.213733  6703 net.cpp:109]     with loss weight 1
# I1219 08:12:19.213799  6703 net.cpp:170] loss needs backward computation.
# I1219 08:12:19.213855  6703 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:19.213891  6703 net.cpp:172] data does not need backward computation.
# I1219 08:12:19.213922  6703 net.cpp:208] This network produces output loss
# I1219 08:12:19.213975  6703 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:19.214011  6703 net.cpp:219] Network initialization done.
# I1219 08:12:19.214045  6703 net.cpp:220] Memory required for data: 284
# I1219 08:12:19.214393  6703 solver.cpp:151] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val.prototxt
# I1219 08:12:19.214450  6703 net.cpp:275] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I1219 08:12:19.214558  6703 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I1219 08:12:19.215701  6703 net.cpp:67] Creating Layer data
# I1219 08:12:19.215749  6703 net.cpp:356] data -> data
# I1219 08:12:19.215814  6703 net.cpp:356] data -> label
# I1219 08:12:19.215854  6703 net.cpp:96] Setting up data
# I1219 08:12:19.215888  6703 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I1219 08:12:19.215970  6703 hdf5_data_layer.cpp:69] Number of files: 1
# I1219 08:12:19.216006  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/test.h5
# I1219 08:12:19.217787  6703 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I1219 08:12:19.217942  6703 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:19.217983  6703 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:19.218018  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218060  6703 net.cpp:67] Creating Layer label_data_1_split
# I1219 08:12:19.218093  6703 net.cpp:394] label_data_1_split <- label
# I1219 08:12:19.218130  6703 net.cpp:356] label_data_1_split -> label_data_1_split_0
# I1219 08:12:19.218339  6703 net.cpp:356] label_data_1_split -> label_data_1_split_1
# I1219 08:12:19.218389  6703 net.cpp:96] Setting up label_data_1_split
# I1219 08:12:19.218431  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218534  6703 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:19.218593  6703 net.cpp:67] Creating Layer fc1
# I1219 08:12:19.218631  6703 net.cpp:394] fc1 <- data
# I1219 08:12:19.218668  6703 net.cpp:356] fc1 -> fc1
# I1219 08:12:19.218708  6703 net.cpp:96] Setting up fc1
# I1219 08:12:19.218752  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.218798  6703 net.cpp:67] Creating Layer fc1_fc1_0_split
# I1219 08:12:19.218848  6703 net.cpp:394] fc1_fc1_0_split <- fc1
# I1219 08:12:19.218888  6703 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_0
# I1219 08:12:19.218925  6703 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_1
# I1219 08:12:19.218962  6703 net.cpp:96] Setting up fc1_fc1_0_split
# I1219 08:12:19.219015  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.219049  6703 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:19.219081  6703 net.cpp:67] Creating Layer loss
# I1219 08:12:19.219135  6703 net.cpp:394] loss <- fc1_fc1_0_split_0
# I1219 08:12:19.219169  6703 net.cpp:394] loss <- label_data_1_split_0
# I1219 08:12:19.219205  6703 net.cpp:356] loss -> loss
# I1219 08:12:19.219243  6703 net.cpp:96] Setting up loss
# I1219 08:12:19.219280  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.219312  6703 net.cpp:109]     with loss weight 1
# I1219 08:12:19.219358  6703 net.cpp:67] Creating Layer accuracy
# I1219 08:12:19.219422  6703 net.cpp:394] accuracy <- fc1_fc1_0_split_1
# I1219 08:12:19.219450  6703 net.cpp:394] accuracy <- label_data_1_split_1
# I1219 08:12:19.219476  6703 net.cpp:356] accuracy -> accuracy
# I1219 08:12:19.219506  6703 net.cpp:96] Setting up accuracy
# I1219 08:12:19.219534  6703 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:19.219558  6703 net.cpp:172] accuracy does not need backward computation.
# I1219 08:12:19.219580  6703 net.cpp:170] loss needs backward computation.
# I1219 08:12:19.219604  6703 net.cpp:170] fc1_fc1_0_split needs backward computation.
# I1219 08:12:19.219627  6703 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:19.219673  6703 net.cpp:172] label_data_1_split does not need backward computation.
# I1219 08:12:19.219699  6703 net.cpp:172] data does not need backward computation.
# I1219 08:12:19.219758  6703 net.cpp:208] This network produces output accuracy
# I1219 08:12:19.219784  6703 net.cpp:208] This network produces output loss
# I1219 08:12:19.219811  6703 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:19.219856  6703 net.cpp:219] Network initialization done.
# I1219 08:12:19.219885  6703 net.cpp:220] Memory required for data: 528
# I1219 08:12:19.219923  6703 solver.cpp:41] Solver scaffolding done.
# I1219 08:12:19.219967  6703 solver.cpp:160] Solving LogisticRegressionNet
# I1219 08:12:19.219998  6703 solver.cpp:247] Iteration 0, Testing net (#0)
# I1219 08:12:19.228442  6703 solver.cpp:298]     Test net output #0: accuracy = 0.6956
# I1219 08:12:19.228569  6703 solver.cpp:298]     Test net output #1: loss = 0.688362 (* 1 = 0.688362 loss)
# I1219 08:12:19.228648  6703 solver.cpp:191] Iteration 0, loss = 0.695054
# I1219 08:12:19.228683  6703 solver.cpp:206]     Train net output #0: loss = 0.695054 (* 1 = 0.695054 loss)
# I1219 08:12:19.228715  6703 solver.cpp:403] Iteration 0, lr = 0.01
# I1219 08:12:19.232967  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.233537  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.236044  6703 solver.cpp:247] Iteration 1000, Testing net (#0)
# I1219 08:12:19.252324  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7552
# I1219 08:12:19.252627  6703 solver.cpp:298]     Test net output #1: loss = 0.594086 (* 1 = 0.594086 loss)
# I1219 08:12:19.252799  6703 solver.cpp:191] Iteration 1000, loss = 0.470893
# I1219 08:12:19.252857  6703 solver.cpp:206]     Train net output #0: loss = 0.470893 (* 1 = 0.470893 loss)
# I1219 08:12:19.252900  6703 solver.cpp:403] Iteration 1000, lr = 0.01
# I1219 08:12:19.256023  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.256152  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.256988  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.261559  6703 solver.cpp:247] Iteration 2000, Testing net (#0)
# I1219 08:12:19.271371  6703 solver.cpp:298]     Test net output #0: accuracy = 0.774
# I1219 08:12:19.271455  6703 solver.cpp:298]     Test net output #1: loss = 0.595628 (* 1 = 0.595628 loss)
# I1219 08:12:19.271498  6703 solver.cpp:191] Iteration 2000, loss = 0.76071
# I1219 08:12:19.271538  6703 solver.cpp:206]     Train net output #0: loss = 0.76071 (* 1 = 0.76071 loss)
# I1219 08:12:19.271669  6703 solver.cpp:403] Iteration 2000, lr = 0.01
# I1219 08:12:19.272680  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.273214  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.277489  6703 solver.cpp:247] Iteration 3000, Testing net (#0)
# I1219 08:12:19.283244  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7628
# I1219 08:12:19.283325  6703 solver.cpp:298]     Test net output #1: loss = 0.593084 (* 1 = 0.593084 loss)
# I1219 08:12:19.283356  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.283411  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.284180  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.284324  6703 solver.cpp:191] Iteration 3000, loss = 0.786944
# I1219 08:12:19.284369  6703 solver.cpp:206]     Train net output #0: loss = 0.786944 (* 1 = 0.786944 loss)
# I1219 08:12:19.284399  6703 solver.cpp:403] Iteration 3000, lr = 0.01
# I1219 08:12:19.290078  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.290947  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.292816  6703 solver.cpp:247] Iteration 4000, Testing net (#0)
# I1219 08:12:19.303151  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7552
# I1219 08:12:19.303288  6703 solver.cpp:298]     Test net output #1: loss = 0.594086 (* 1 = 0.594086 loss)
# I1219 08:12:19.303395  6703 solver.cpp:191] Iteration 4000, loss = 0.470893
# I1219 08:12:19.303429  6703 solver.cpp:206]     Train net output #0: loss = 0.470893 (* 1 = 0.470893 loss)
# I1219 08:12:19.303457  6703 solver.cpp:403] Iteration 4000, lr = 0.01
# I1219 08:12:19.306126  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.306265  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.307286  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.309453  6703 solver.cpp:247] Iteration 5000, Testing net (#0)
# I1219 08:12:19.317893  6703 solver.cpp:298]     Test net output #0: accuracy = 0.774
# I1219 08:12:19.317991  6703 solver.cpp:298]     Test net output #1: loss = 0.595628 (* 1 = 0.595628 loss)
# I1219 08:12:19.318050  6703 solver.cpp:191] Iteration 5000, loss = 0.76071
# I1219 08:12:19.318096  6703 solver.cpp:206]     Train net output #0: loss = 0.76071 (* 1 = 0.76071 loss)
# I1219 08:12:19.318136  6703 solver.cpp:403] Iteration 5000, lr = 0.001
# I1219 08:12:19.320324  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.320791  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.325198  6703 solver.cpp:247] Iteration 6000, Testing net (#0)
# I1219 08:12:19.333302  6703 solver.cpp:298]     Test net output #0: accuracy = 0.761601
# I1219 08:12:19.333483  6703 solver.cpp:298]     Test net output #1: loss = 0.591837 (* 1 = 0.591837 loss)
# I1219 08:12:19.333539  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.333580  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.334617  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.334795  6703 solver.cpp:191] Iteration 6000, loss = 0.772234
# I1219 08:12:19.334863  6703 solver.cpp:206]     Train net output #0: loss = 0.772234 (* 1 = 0.772234 loss)
# I1219 08:12:19.334911  6703 solver.cpp:403] Iteration 6000, lr = 0.001
# I1219 08:12:19.339965  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.340620  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.341912  6703 solver.cpp:247] Iteration 7000, Testing net (#0)
# I1219 08:12:19.349477  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7664
# I1219 08:12:19.349639  6703 solver.cpp:298]     Test net output #1: loss = 0.59251 (* 1 = 0.59251 loss)
# I1219 08:12:19.349696  6703 solver.cpp:191] Iteration 7000, loss = 0.516432
# I1219 08:12:19.349730  6703 solver.cpp:206]     Train net output #0: loss = 0.516432 (* 1 = 0.516432 loss)
# I1219 08:12:19.349758  6703 solver.cpp:403] Iteration 7000, lr = 0.001
# I1219 08:12:19.352972  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.353129  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.353811  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.357167  6703 solver.cpp:247] Iteration 8000, Testing net (#0)
# I1219 08:12:19.363391  6703 solver.cpp:298]     Test net output #0: accuracy = 0.768
# I1219 08:12:19.363477  6703 solver.cpp:298]     Test net output #1: loss = 0.591181 (* 1 = 0.591181 loss)
# I1219 08:12:19.363528  6703 solver.cpp:191] Iteration 8000, loss = 0.795977
# I1219 08:12:19.363560  6703 solver.cpp:206]     Train net output #0: loss = 0.795977 (* 1 = 0.795977 loss)
# I1219 08:12:19.363591  6703 solver.cpp:403] Iteration 8000, lr = 0.001
# I1219 08:12:19.364802  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.365473  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.368908  6703 solver.cpp:247] Iteration 9000, Testing net (#0)
# I1219 08:12:19.374877  6703 solver.cpp:298]     Test net output #0: accuracy = 0.762801
# I1219 08:12:19.375004  6703 solver.cpp:298]     Test net output #1: loss = 0.591795 (* 1 = 0.591795 loss)
# I1219 08:12:19.375072  6703 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:19.375097  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.375604  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.375681  6703 solver.cpp:191] Iteration 9000, loss = 0.77468
# I1219 08:12:19.375772  6703 solver.cpp:206]     Train net output #0: loss = 0.77468 (* 1 = 0.77468 loss)
# I1219 08:12:19.375802  6703 solver.cpp:403] Iteration 9000, lr = 0.001
# I1219 08:12:19.379832  6703 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:19.380620  6703 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:19.382009  6703 solver.cpp:317] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I1219 08:12:19.382411  6703 solver.cpp:324] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.solverstate
# I1219 08:12:19.382501  6703 solver.cpp:228] Iteration 10000, loss = 0.516244
# I1219 08:12:19.382596  6703 solver.cpp:247] Iteration 10000, Testing net (#0)
# I1219 08:12:19.388818  6703 solver.cpp:298]     Test net output #0: accuracy = 0.7664
# I1219 08:12:19.389006  6703 solver.cpp:298]     Test net output #1: loss = 0.592505 (* 1 = 0.592505 loss)
# I1219 08:12:19.389040  6703 solver.cpp:233] Optimization Done.
# I1219 08:12:19.389065  6703 caffe.cpp:121] Optimization Done.

# %% [markdown]
# If you look at the `train_val.prototxt`, you'll see that it's simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer neural network.
# That network is given in `train_val2.prototxt`, and that's the only change made in `solver2.prototxt` which we will now use.
#
# The final accuracy of the network we'll train below should be higher than for the network above!

# %%
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver2.prototxt
# Out:
# ./build/tools/caffe: /home/sronen/anaconda/lib/libtiff.so.5: no version information available (required by /usr/lib/x86_64-linux-gnu/libopencv_highgui.so.2.4)
# I1219 08:12:30.957481  6707 caffe.cpp:103] Use CPU.
# I1219 08:12:30.958391  6707 caffe.cpp:107] Starting Optimization
# I1219 08:12:30.958576  6707 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val2.prototxt"
# I1219 08:12:30.959024  6707 solver.cpp:67] Creating training net from net file: examples/hdf5_classification/train_val2.prototxt
# I1219 08:12:30.960527  6707 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I1219 08:12:30.960847  6707 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I1219 08:12:30.964094  6707 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I1219 08:12:30.968000  6707 net.cpp:67] Creating Layer data
# I1219 08:12:30.968276  6707 net.cpp:356] data -> data
# I1219 08:12:30.968329  6707 net.cpp:356] data -> label
# I1219 08:12:30.968883  6707 net.cpp:96] Setting up data
# I1219 08:12:30.968935  6707 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I1219 08:12:30.969331  6707 hdf5_data_layer.cpp:69] Number of files: 2
# I1219 08:12:30.969569  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:30.974823  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:30.974952  6707 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:30.975005  6707 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:30.975041  6707 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:30.975090  6707 net.cpp:67] Creating Layer fc1
# I1219 08:12:30.975126  6707 net.cpp:394] fc1 <- data
# I1219 08:12:30.975170  6707 net.cpp:356] fc1 -> fc1
# I1219 08:12:30.975229  6707 net.cpp:96] Setting up fc1
# I1219 08:12:30.975626  6707 net.cpp:103] Top shape: 10 40 1 1 (400)
# I1219 08:12:30.975742  6707 net.cpp:67] Creating Layer relu1
# I1219 08:12:30.975781  6707 net.cpp:394] relu1 <- fc1
# I1219 08:12:30.975816  6707 net.cpp:345] relu1 -> fc1 (in-place)
# I1219 08:12:30.975852  6707 net.cpp:96] Setting up relu1
# I1219 08:12:30.975886  6707 net.cpp:103] Top shape: 10 40 1 1 (400)
# I1219 08:12:30.975968  6707 net.cpp:67] Creating Layer fc2
# I1219 08:12:30.976006  6707 net.cpp:394] fc2 <- fc1
# I1219 08:12:30.976045  6707 net.cpp:356] fc2 -> fc2
# I1219 08:12:30.976083  6707 net.cpp:96] Setting up fc2
# I1219 08:12:30.976131  6707 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:30.976176  6707 net.cpp:67] Creating Layer loss
# I1219 08:12:30.976209  6707 net.cpp:394] loss <- fc2
# I1219 08:12:30.976264  6707 net.cpp:394] loss <- label
# I1219 08:12:30.976302  6707 net.cpp:356] loss -> loss
# I1219 08:12:30.976339  6707 net.cpp:96] Setting up loss
# I1219 08:12:30.976385  6707 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:30.976419  6707 net.cpp:109]     with loss weight 1
# I1219 08:12:30.976501  6707 net.cpp:170] loss needs backward computation.
# I1219 08:12:30.976575  6707 net.cpp:170] fc2 needs backward computation.
# I1219 08:12:30.976610  6707 net.cpp:170] relu1 needs backward computation.
# I1219 08:12:30.976642  6707 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:30.976675  6707 net.cpp:172] data does not need backward computation.
# I1219 08:12:30.976707  6707 net.cpp:208] This network produces output loss
# I1219 08:12:30.976739  6707 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:30.976794  6707 net.cpp:219] Network initialization done.
# I1219 08:12:30.976826  6707 net.cpp:220] Memory required for data: 3484
# I1219 08:12:30.976994  6707 solver.cpp:151] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val2.prototxt
# I1219 08:12:30.977881  6707 net.cpp:275] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I1219 08:12:30.978025  6707 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I1219 08:12:30.979822  6707 net.cpp:67] Creating Layer data
# I1219 08:12:30.979874  6707 net.cpp:356] data -> data
# I1219 08:12:30.979918  6707 net.cpp:356] data -> label
# I1219 08:12:30.979956  6707 net.cpp:96] Setting up data
# I1219 08:12:30.979990  6707 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I1219 08:12:30.980077  6707 hdf5_data_layer.cpp:69] Number of files: 1
# I1219 08:12:30.980116  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/test.h5
# I1219 08:12:30.982192  6707 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I1219 08:12:30.982262  6707 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I1219 08:12:30.982552  6707 net.cpp:103] Top shape: 10 4 1 1 (40)
# I1219 08:12:30.982590  6707 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:30.982633  6707 net.cpp:67] Creating Layer label_data_1_split
# I1219 08:12:30.982668  6707 net.cpp:394] label_data_1_split <- label
# I1219 08:12:30.982707  6707 net.cpp:356] label_data_1_split -> label_data_1_split_0
# I1219 08:12:30.982749  6707 net.cpp:356] label_data_1_split -> label_data_1_split_1
# I1219 08:12:30.982787  6707 net.cpp:96] Setting up label_data_1_split
# I1219 08:12:30.982856  6707 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:30.982894  6707 net.cpp:103] Top shape: 10 1 1 1 (10)
# I1219 08:12:30.982935  6707 net.cpp:67] Creating Layer fc1
# I1219 08:12:30.982969  6707 net.cpp:394] fc1 <- data
# I1219 08:12:30.983006  6707 net.cpp:356] fc1 -> fc1
# I1219 08:12:30.983049  6707 net.cpp:96] Setting up fc1
# I1219 08:12:30.983139  6707 net.cpp:103] Top shape: 10 40 1 1 (400)
# I1219 08:12:30.983189  6707 net.cpp:67] Creating Layer relu1
# I1219 08:12:30.983224  6707 net.cpp:394] relu1 <- fc1
# I1219 08:12:30.983261  6707 net.cpp:345] relu1 -> fc1 (in-place)
# I1219 08:12:30.983299  6707 net.cpp:96] Setting up relu1
# I1219 08:12:30.983348  6707 net.cpp:103] Top shape: 10 40 1 1 (400)
# I1219 08:12:30.983429  6707 net.cpp:67] Creating Layer fc2
# I1219 08:12:30.983465  6707 net.cpp:394] fc2 <- fc1
# I1219 08:12:30.983525  6707 net.cpp:356] fc2 -> fc2
# I1219 08:12:30.983563  6707 net.cpp:96] Setting up fc2
# I1219 08:12:30.983631  6707 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:30.983680  6707 net.cpp:67] Creating Layer fc2_fc2_0_split
# I1219 08:12:30.983717  6707 net.cpp:394] fc2_fc2_0_split <- fc2
# I1219 08:12:30.983755  6707 net.cpp:356] fc2_fc2_0_split -> fc2_fc2_0_split_0
# I1219 08:12:30.983799  6707 net.cpp:356] fc2_fc2_0_split -> fc2_fc2_0_split_1
# I1219 08:12:30.983856  6707 net.cpp:96] Setting up fc2_fc2_0_split
# I1219 08:12:30.983894  6707 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:30.983932  6707 net.cpp:103] Top shape: 10 2 1 1 (20)
# I1219 08:12:30.983975  6707 net.cpp:67] Creating Layer loss
# I1219 08:12:30.984036  6707 net.cpp:394] loss <- fc2_fc2_0_split_0
# I1219 08:12:30.984078  6707 net.cpp:394] loss <- label_data_1_split_0
# I1219 08:12:30.984119  6707 net.cpp:356] loss -> loss
# I1219 08:12:30.984160  6707 net.cpp:96] Setting up loss
# I1219 08:12:30.984220  6707 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:30.984261  6707 net.cpp:109]     with loss weight 1
# I1219 08:12:30.984320  6707 net.cpp:67] Creating Layer accuracy
# I1219 08:12:30.984361  6707 net.cpp:394] accuracy <- fc2_fc2_0_split_1
# I1219 08:12:30.984403  6707 net.cpp:394] accuracy <- label_data_1_split_1
# I1219 08:12:30.984447  6707 net.cpp:356] accuracy -> accuracy
# I1219 08:12:30.984495  6707 net.cpp:96] Setting up accuracy
# I1219 08:12:30.984558  6707 net.cpp:103] Top shape: 1 1 1 1 (1)
# I1219 08:12:30.984601  6707 net.cpp:172] accuracy does not need backward computation.
# I1219 08:12:30.984644  6707 net.cpp:170] loss needs backward computation.
# I1219 08:12:30.984685  6707 net.cpp:170] fc2_fc2_0_split needs backward computation.
# I1219 08:12:30.984722  6707 net.cpp:170] fc2 needs backward computation.
# I1219 08:12:30.984758  6707 net.cpp:170] relu1 needs backward computation.
# I1219 08:12:30.984793  6707 net.cpp:170] fc1 needs backward computation.
# I1219 08:12:30.984848  6707 net.cpp:172] label_data_1_split does not need backward computation.
# I1219 08:12:30.984886  6707 net.cpp:172] data does not need backward computation.
# I1219 08:12:30.984922  6707 net.cpp:208] This network produces output accuracy
# I1219 08:12:30.984982  6707 net.cpp:208] This network produces output loss
# I1219 08:12:30.985030  6707 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I1219 08:12:30.985074  6707 net.cpp:219] Network initialization done.
# I1219 08:12:30.985111  6707 net.cpp:220] Memory required for data: 3728
# I1219 08:12:30.985194  6707 solver.cpp:41] Solver scaffolding done.
# I1219 08:12:30.985240  6707 solver.cpp:160] Solving LogisticRegressionNet
# I1219 08:12:30.985291  6707 solver.cpp:247] Iteration 0, Testing net (#0)
# I1219 08:12:30.999091  6707 solver.cpp:298]     Test net output #0: accuracy = 0.48
# I1219 08:12:30.999318  6707 solver.cpp:298]     Test net output #1: loss = 0.693131 (* 1 = 0.693131 loss)
# I1219 08:12:30.999487  6707 solver.cpp:191] Iteration 0, loss = 0.69283
# I1219 08:12:30.999547  6707 solver.cpp:206]     Train net output #0: loss = 0.69283 (* 1 = 0.69283 loss)
# I1219 08:12:30.999661  6707 solver.cpp:403] Iteration 0, lr = 0.01
# I1219 08:12:31.015357  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.016592  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.022196  6707 solver.cpp:247] Iteration 1000, Testing net (#0)
# I1219 08:12:31.035399  6707 solver.cpp:298]     Test net output #0: accuracy = 0.7644
# I1219 08:12:31.035548  6707 solver.cpp:298]     Test net output #1: loss = 0.504556 (* 1 = 0.504556 loss)
# I1219 08:12:31.035620  6707 solver.cpp:191] Iteration 1000, loss = 0.418397
# I1219 08:12:31.035657  6707 solver.cpp:206]     Train net output #0: loss = 0.418397 (* 1 = 0.418397 loss)
# I1219 08:12:31.035686  6707 solver.cpp:403] Iteration 1000, lr = 0.01
# I1219 08:12:31.045101  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.045306  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.046210  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.057101  6707 solver.cpp:247] Iteration 2000, Testing net (#0)
# I1219 08:12:31.068461  6707 solver.cpp:298]     Test net output #0: accuracy = 0.7828
# I1219 08:12:31.068606  6707 solver.cpp:298]     Test net output #1: loss = 0.475529 (* 1 = 0.475529 loss)
# I1219 08:12:31.068662  6707 solver.cpp:191] Iteration 2000, loss = 0.564664
# I1219 08:12:31.068696  6707 solver.cpp:206]     Train net output #0: loss = 0.564664 (* 1 = 0.564664 loss)
# I1219 08:12:31.068724  6707 solver.cpp:403] Iteration 2000, lr = 0.01
# I1219 08:12:31.074820  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.075726  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.091408  6707 solver.cpp:247] Iteration 3000, Testing net (#0)
# I1219 08:12:31.106379  6707 solver.cpp:298]     Test net output #0: accuracy = 0.806401
# I1219 08:12:31.106528  6707 solver.cpp:298]     Test net output #1: loss = 0.436446 (* 1 = 0.436446 loss)
# I1219 08:12:31.106580  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.106624  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.107507  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.107664  6707 solver.cpp:191] Iteration 3000, loss = 0.428448
# I1219 08:12:31.107729  6707 solver.cpp:206]     Train net output #0: loss = 0.428448 (* 1 = 0.428448 loss)
# I1219 08:12:31.107790  6707 solver.cpp:403] Iteration 3000, lr = 0.01
# I1219 08:12:31.121211  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.122257  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.128211  6707 solver.cpp:247] Iteration 4000, Testing net (#0)
# I1219 08:12:31.142933  6707 solver.cpp:298]     Test net output #0: accuracy = 0.8032
# I1219 08:12:31.143110  6707 solver.cpp:298]     Test net output #1: loss = 0.438708 (* 1 = 0.438708 loss)
# I1219 08:12:31.143198  6707 solver.cpp:191] Iteration 4000, loss = 0.360664
# I1219 08:12:31.143254  6707 solver.cpp:206]     Train net output #0: loss = 0.360664 (* 1 = 0.360664 loss)
# I1219 08:12:31.143304  6707 solver.cpp:403] Iteration 4000, lr = 0.01
# I1219 08:12:31.156522  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.156690  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.157632  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.167949  6707 solver.cpp:247] Iteration 5000, Testing net (#0)
# I1219 08:12:31.180024  6707 solver.cpp:298]     Test net output #0: accuracy = 0.8056
# I1219 08:12:31.180124  6707 solver.cpp:298]     Test net output #1: loss = 0.434303 (* 1 = 0.434303 loss)
# I1219 08:12:31.180199  6707 solver.cpp:191] Iteration 5000, loss = 0.438637
# I1219 08:12:31.180263  6707 solver.cpp:206]     Train net output #0: loss = 0.438637 (* 1 = 0.438637 loss)
# I1219 08:12:31.180307  6707 solver.cpp:403] Iteration 5000, lr = 0.001
# I1219 08:12:31.186034  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.187563  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.203840  6707 solver.cpp:247] Iteration 6000, Testing net (#0)
# I1219 08:12:31.215301  6707 solver.cpp:298]     Test net output #0: accuracy = 0.821201
# I1219 08:12:31.215473  6707 solver.cpp:298]     Test net output #1: loss = 0.412224 (* 1 = 0.412224 loss)
# I1219 08:12:31.215533  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.215574  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.216631  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.216878  6707 solver.cpp:191] Iteration 6000, loss = 0.412019
# I1219 08:12:31.216927  6707 solver.cpp:206]     Train net output #0: loss = 0.412019 (* 1 = 0.412019 loss)
# I1219 08:12:31.216955  6707 solver.cpp:403] Iteration 6000, lr = 0.001
# I1219 08:12:31.229383  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.229874  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.234233  6707 solver.cpp:247] Iteration 7000, Testing net (#0)
# I1219 08:12:31.247138  6707 solver.cpp:298]     Test net output #0: accuracy = 0.821601
# I1219 08:12:31.247334  6707 solver.cpp:298]     Test net output #1: loss = 0.410561 (* 1 = 0.410561 loss)
# I1219 08:12:31.247426  6707 solver.cpp:191] Iteration 7000, loss = 0.325405
# I1219 08:12:31.247480  6707 solver.cpp:206]     Train net output #0: loss = 0.325405 (* 1 = 0.325405 loss)
# I1219 08:12:31.247527  6707 solver.cpp:403] Iteration 7000, lr = 0.001
# I1219 08:12:31.257511  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.257663  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.258872  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.270126  6707 solver.cpp:247] Iteration 8000, Testing net (#0)
# I1219 08:12:31.284680  6707 solver.cpp:298]     Test net output #0: accuracy = 0.820001
# I1219 08:12:31.284821  6707 solver.cpp:298]     Test net output #1: loss = 0.409148 (* 1 = 0.409148 loss)
# I1219 08:12:31.284876  6707 solver.cpp:191] Iteration 8000, loss = 0.404165
# I1219 08:12:31.284910  6707 solver.cpp:206]     Train net output #0: loss = 0.404165 (* 1 = 0.404165 loss)
# I1219 08:12:31.284939  6707 solver.cpp:403] Iteration 8000, lr = 0.001
# I1219 08:12:31.288831  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.289594  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.303395  6707 solver.cpp:247] Iteration 9000, Testing net (#0)
# I1219 08:12:31.315449  6707 solver.cpp:298]     Test net output #0: accuracy = 0.822401
# I1219 08:12:31.315589  6707 solver.cpp:298]     Test net output #1: loss = 0.408748 (* 1 = 0.408748 loss)
# I1219 08:12:31.315620  6707 hdf5_data_layer.cpp:99] looping around to first file
# I1219 08:12:31.315645  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.316064  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.316148  6707 solver.cpp:191] Iteration 9000, loss = 0.403848
# I1219 08:12:31.316277  6707 solver.cpp:206]     Train net output #0: loss = 0.403848 (* 1 = 0.403848 loss)
# I1219 08:12:31.316421  6707 solver.cpp:403] Iteration 9000, lr = 0.001
# I1219 08:12:31.332415  6707 hdf5_data_layer.cpp:29] Loading HDF5 file/home/sronen/caffe/examples/hdf5_classification/data/train.h5
# I1219 08:12:31.333271  6707 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I1219 08:12:31.337380  6707 solver.cpp:317] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I1219 08:12:31.337774  6707 solver.cpp:324] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.solverstate
# I1219 08:12:31.337975  6707 solver.cpp:228] Iteration 10000, loss = 0.319705
# I1219 08:12:31.338018  6707 solver.cpp:247] Iteration 10000, Testing net (#0)
# I1219 08:12:31.348179  6707 solver.cpp:298]     Test net output #0: accuracy = 0.820401
# I1219 08:12:31.348251  6707 solver.cpp:298]     Test net output #1: loss = 0.408059 (* 1 = 0.408059 loss)
# I1219 08:12:31.348279  6707 solver.cpp:233] Optimization Done.
# I1219 08:12:31.348304  6707 caffe.cpp:121] Optimization Done.

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
